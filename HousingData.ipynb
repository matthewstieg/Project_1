# %%
 # Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import json
from pprint import pprint
import csv
import quandl

# quandl.ApiConfig.api_key = "UXe8DsKw9x6v1TnQn25C"

# Import API key
api_key = "UXe8DsKw9x6v1TnQn25C"
# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-48-67f8e41400a5> in <module>
#       9 import csv
#      10 import quandl
# ---> 11 from DataFrame import df
#      12 # quandl.ApiConfig.api_key = "UXe8DsKw9x6v1TnQn25C"
#      13
#
# ModuleNotFoundError: No module named 'DataFrame'

# %%
## area_categorytest = "S
area_codetest = "2"
indicator_codetest = "MVALFAH"
frequencytest = "annual"
numberofrowstest = "11"
# Zillow - Median Value Per Square Foot - All Homes|MVALFA

test_url = f"https://www.quandl.com/api/v3/datasets/ZILLOW/{area_categorytest}{area_codetest}_{indicator_codetest}?&collapse={frequencytest}&rows={numberofrowstest}"

responsetest = requests.get(test_url).json()

# pprint(responsetest)
# curl 'https://www.quandl.com/api/v3/datasets/ZILLOW/S2_MVALFAH?api_key=UXe8DsKw9x6v1TnQn25C'

# %%
statesdf = pd.read_csv("StateList.csv")
print(statesdf)
# Out:
#                     AREA  CODE
# 0                 Alaska     2
# 1                Alabama     3
# 2               Arkansas     4
# 3                Arizona     5
# 4             California     6
# 5               Colorado     7
# 6            Connecticut     8
# 7   District of Columbia     9
# 8               Delaware    10
# 9                Florida    11
# 10               Georgia    12
# 11                Hawaii    13
# 12                  Iowa    14
# 13                 Idaho    15
# 14              Illinois    16
# 15               Indiana    17
# 16                Kansas    18
# 17              Kentucky    19
# 18             Louisiana    20
# 19         Massachusetts    21
# 20              Maryland    22
# 21              Michigan    23
# 22             Minnesota    24
# 23              Missouri    25
# 24           Mississippi    26
# 25               Montana    27
# 26        North Carolina    28
# 27          North Dakota    29
# 28              Nebraska    30
# 29         New Hampshire    31
# 30            New Jersey    32
# 31            New Mexico    33
# 32                Nevada    34
# 33              New York    35
# 34                  Ohio    36
# 35              Oklahoma    37
# 36                Oregon    38
# 37          Pennsylvania    39
# 38          Rhode Island    40
# 39        South Carolina    40
# 40             Tennessee    42
# 41                 Texas    43
# 42                  Utah    44
# 43              Virginia    45
# 44               Vermont    46
# 45            Washington    47
# 46             Wisconsin    48
# 47         West Virginia    49
# 48               Wyoming    50
# 49                 Maine    51
# 50          South Dakota    52

# %%
# stateidcounter = 1

codes = list(range(2,53))
states = []
dollar_per_sqft_median = []


for code in codes:
    area_code = f"{code}"
    area_category = "S"
    indicator_code = "MVALFAH"
    frequency = "annual"
    numberofrows = "11"
    base_url = f"https://www.quandl.com/api/v3/datasets/ZILLOW/{area_category}{area_code}_{indicator_code}?&collapse={frequency}&rows={numberofrows}&"
    try:
        response1 = requests.get(base_url)
        response1json = response1.json()
        print(code)
        pprint(response1)
    except:
        print(code)
#     dollar_per_sqft_median.append(response1['dataset']['data'][0])





# print(response1)
# Out:
# 2
# <Response [200]>
# 3
# <Response [200]>
# 4
# 5
# <Response [200]>
# 6
# <Response [200]>
# 7
# <Response [200]>
# 8
# <Response [200]>
# 9
# <Response [200]>
# 10
# <Response [200]>
# 11
# <Response [200]>
# 12
# 13
# <Response [200]>
# 14
# <Response [200]>
# 15
# <Response [200]>
# 16
# <Response [200]>
# 17
# <Response [200]>
# 18
# <Response [200]>
# 19
# <Response [200]>
# 20
# <Response [200]>
# 21
# <Response [200]>
# 22
# <Response [200]>
# 23
# 24
# <Response [200]>
# 25
# <Response [200]>
# 26
# <Response [200]>
# 27
# 28
# 29
# <Response [200]>
# 30
# 31
# 32
# <Response [200]>
# 33
# <Response [200]>
# 34
# <Response [200]>
# 35
# <Response [200]>
# 36
# <Response [200]>
# 37
# <Response [200]>
# 38
# <Response [200]>
# 39
# <Response [200]>
# 40
# 41
# <Response [200]>
# 42
# <Response [200]>
# 43
# <Response [200]>
# 44
# <Response [200]>
# 45
# 46
# <Response [200]>
# 47
# 48
# 49
# 50
# <Response [200]>
# 51
# 52
# <Response [200]>
